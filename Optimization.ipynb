# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_bin = application_df["APPLICATION_TYPE"].value_counts()
app_bin
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
app_dict = app_bin.to_dict()
application_types_to_replace = [k for k, t in app_dict.items() if t <500]

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification = application_df["CLASSIFICATION"].value_counts()
classification
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_more_than_1 = classification[classification > 1]
class_more_than_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
class_dict = classification.to_dict()
classifications_to_replace = [k for k, c in class_dict.items() if c <1000]

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"].values
X = application_df.drop(columns="IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# First Attempt: Increasing Neurons

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
no_of_features = len(X_train[0])

nn1 = tf.keras.models.Sequential()

# First hidden layer
nn1.add(tf.keras.layers.Dense(units=100, activation="relu", input_dim=no_of_features))

# Second hidden layer
nn1.add(tf.keras.layers.Dense(units=80, activation="relu"))

# Output layer
nn1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 100)               4400
#
#  dense_4 (Dense)             (None, 80)                8080
#
#  dense_5 (Dense)             (None, 1)                 81
#
# ...
# Total params: 12,561
# Trainable params: 12,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn1.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
nn1.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5707 - accuracy: 0.7224
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5570 - accuracy: 0.7301
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5530 - accuracy: 0.7309
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5508 - accuracy: 0.7327
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5496 - accuracy: 0.7334
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7334
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7342
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7339
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7337
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5619 - accuracy: 0.7265 - 533ms/epoch - 2ms/step
# Loss: 0.5619180798530579, Accuracy: 0.7265306115150452

# %% [markdown]
# Second Attempt: Increasing Layer

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
no_of_features = len(X_train[0])

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=no_of_features))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=50, activation="relu"))

# Third hidden layer
nn2.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 80)                3520
#
#  dense_7 (Dense)             (None, 50)                4050
#
#  dense_8 (Dense)             (None, 30)                1530
#
#  dense_9 (Dense)             (None, 1)                 31
#
# ...
# Total params: 9,131
# Trainable params: 9,131
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
nn2.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5662 - accuracy: 0.7250
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7299
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5512 - accuracy: 0.7336
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7338
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7349
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7345
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7352
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7354
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7362
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5739 - accuracy: 0.7248 - 500ms/epoch - 2ms/step
# Loss: 0.5739367604255676, Accuracy: 0.724781334400177

# %% [markdown]
# Third Attempt: Using a Different Activation Function

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
no_of_features = len(X_train[0])

nn3 = tf.keras.models.Sequential()
from keras.layers import LeakyReLU

# First hidden layer
nn3.add(tf.keras.layers.Dense(units=80, input_dim=no_of_features))
nn3.add(LeakyReLU(alpha=0.05))

# Second hidden layer
nn3.add(tf.keras.layers.Dense(units=30))
nn3.add(LeakyReLU(alpha=0.05))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_11 (Dense)            (None, 80)                3520
#
#  leaky_re_lu (LeakyReLU)     (None, 80)                0
#
#  dense_12 (Dense)            (None, 30)                2430
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 30)                0
#
#  dense_13 (Dense)            (None, 1)                 31
#
# ...
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn3.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
nn3.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5695 - accuracy: 0.7251
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5569 - accuracy: 0.7304
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7306
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5522 - accuracy: 0.7299
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7321
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5498 - accuracy: 0.7339
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5495 - accuracy: 0.7313
# Epoch 8/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5484 - accuracy: 0.7325
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7336
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5558 - accuracy: 0.7270 - 508ms/epoch - 2ms/step
# Loss: 0.5558162331581116, Accuracy: 0.7269970774650574

# %% [markdown]
# Fourth Attempt: Increase Neuron, Increase Layer and Change Activation Function

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
no_of_features = len(X_train[0])

nn4 = tf.keras.models.Sequential()
from keras.layers import LeakyReLU

# First hidden layer
nn4.add(tf.keras.layers.Dense(units=80, input_dim=no_of_features))
nn4.add(LeakyReLU(alpha=0.05))

# Second hidden layer
nn4.add(tf.keras.layers.Dense(units=50))
nn4.add(LeakyReLU(alpha=0.05))

# Third hidden layer
nn4.add(tf.keras.layers.Dense(units=30))
nn4.add(LeakyReLU(alpha=0.05))

# Output layer
nn4.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn4.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_14 (Dense)            (None, 80)                3520
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 80)                0
#
#  dense_15 (Dense)            (None, 50)                4050
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 50)                0
#
#  dense_16 (Dense)            (None, 30)                1530
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 30)                0
#
#  dense_17 (Dense)            (None, 1)                 31
#
# ...
# Total params: 9,131
# Trainable params: 9,131
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn4.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
nn4.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5689 - accuracy: 0.7215
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7306
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5505 - accuracy: 0.7324
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7322
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5487 - accuracy: 0.7329
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5475 - accuracy: 0.7336
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7348
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7358
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7365
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn4.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5619 - accuracy: 0.7262 - 494ms/epoch - 2ms/step
# Loss: 0.561881422996521, Accuracy: 0.7261807322502136

# %% [markdown]
# Final Attempt: Increase Neuron, Increase Layer, Change Activation Function and Reduce Epoch

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
no_of_features = len(X_train[0])

nn5 = tf.keras.models.Sequential()
from keras.layers import LeakyReLU

# First hidden layer
nn5.add(tf.keras.layers.Dense(units=80, input_dim=no_of_features))
nn5.add(LeakyReLU(alpha=0.05))

# Second hidden layer
nn5.add(tf.keras.layers.Dense(units=50))
nn5.add(LeakyReLU(alpha=0.05))

# Third hidden layer
nn5.add(tf.keras.layers.Dense(units=30))
nn5.add(LeakyReLU(alpha=0.05))

# Output layer
nn5.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn5.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 80)                3520
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 80)                0
#
#  dense_19 (Dense)            (None, 50)                4050
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 50)                0
#
#  dense_20 (Dense)            (None, 30)                1530
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 30)                0
#
#  dense_21 (Dense)            (None, 1)                 31
#
# ...
# Total params: 9,131
# Trainable params: 9,131
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn5.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Train the model
nn5.fit(X_train_scaled,y_train,epochs=25)
# Out:
# Epoch 1/25
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5714 - accuracy: 0.7227
# Epoch 2/25
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5565 - accuracy: 0.7311
# Epoch 3/25
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5530 - accuracy: 0.7314
# Epoch 4/25
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5506 - accuracy: 0.7328
# Epoch 5/25
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7328
# Epoch 6/25
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7332
# Epoch 7/25
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5480 - accuracy: 0.7332
# Epoch 8/25
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7357
# Epoch 9/25
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7341
# Epoch 10/25
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn5.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5522 - accuracy: 0.7279 - 480ms/epoch - 2ms/step
# Loss: 0.5522438883781433, Accuracy: 0.7279300093650818

# %%
# Export our model to HDF5 file
nn5.save("AlphabetSoupCharity_Optimization.h5")
